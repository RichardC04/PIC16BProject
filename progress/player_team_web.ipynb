# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import urllib.parse
from selenium.webdriver.common.keys import Keys
import pandas as pd
import re

# %%
def get_all_team_links(url="https://gol.gg/teams/list/season-S6/split-ALL/tournament-ALL/"):
    """
    Opens the teams page, scrapes the teams table,
    and returns a dictionary {team_name: team_link, ...}.
    """
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
    driver.get(url)
    time.sleep(3)  # wait for page to load
    #Type "LCK" into the Leagues input (Selectize control)
    league_input = driver.find_element(By.CSS_SELECTOR, ".selectize-control.multi .selectize-input input")
    league_input.send_keys("LCK")
    time.sleep(1)
    league_input.send_keys(Keys.ENTER)  # finalize selection
    time.sleep(2)

    #Click the "Refresh" button to apply the LCK filter
    refresh_button = driver.find_element(By.ID, "btn_refresh")
    refresh_button.click()
    time.sleep(5)
    team_links = {}

    try:
        soup = BeautifulSoup(driver.page_source, "html.parser")
        # Adjust the selector to match the teams table on the page
        table = soup.select_one("table.table_list.playerslist.tablesaw.trhover.tablesaw-swipe.tablesaw-sortable")
        if not table:
            print("Teams table not found on the page.")
            return team_links

        rows = table.find_all("tr")
        if len(rows) < 2:
            print("No team rows found in the table.")
            return team_links

        # Loop over all rows except the header row
        for row in rows[1:]:
            cells = row.find_all(["td", "th"])
            if not cells:
                continue

            # The first cell contains the team name and link
            team_name = cells[0].get_text(strip=True)
            link_tag = cells[0].find("a")
            if link_tag and "href" in link_tag.attrs:
                relative_link = link_tag["href"]
                # Remove the leading '.' if present
                if relative_link.startswith("."):
                    relative_link = relative_link[1:] #remove the . at the beginning
                
                # Build the full URL
                team_link = "https://gol.gg/teams" + relative_link
                team_links[team_name] = team_link

    finally:
        driver.quit()

    return team_links

# %%
def get_team_rosters(links_dict, year):
    """
    Given a dictionary of {team_name: team_url},
    navigates to each team's page, finds the roster table,
    and extracts a list of player names.
    
    Returns a dictionary: { team_name: [player1, player2, ...], ... }
    """
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
    team_rosters = {}

    try:
        for team_name, team_url in links_dict.items():
            print(f"Scraping roster for team: {team_name} -> {team_url}")
            driver.get(team_url)
            time.sleep(3)
            soup = BeautifulSoup(driver.page_source, "html.parser")
            team_name = team_name + " " + year
            # Locate the roster table by its classes
            roster_table = soup.select_one("table.table_list.footable.toggle-square-filled.footable-loaded.default")
            if not roster_table:
                print(f"No roster table found for {team_name}")
                team_rosters[team_name] = []
                continue

            # Parse each row to get player names
            player_names = []
            rows = roster_table.find_all("tr")
            for row in rows:
                cells = row.find_all("td")
                # Based on your screenshot, the second cell might contain the player's name.
                # If the table columns are [ROLE, PLAYER, KDA, ...], then index 1 = player name.
                if len(cells) >= 2:
                    player_name = cells[1].get_text(strip=True)
                    # Make sure it's not an empty row or header row
                    if player_name:
                        player_names.append(player_name)

            team_rosters[team_name] = player_names

    finally:
        driver.quit()

    return team_rosters

# %%
base = "https://gol.gg/teams/list/season-S{}/split-ALL/tournament-ALL/"
team_rosters_dict = {}

for season in range(6, 15):
    url = base.format(season)
    team_links = get_all_team_links(url)
    year = f"S{season}"
# Scraping roster for team: DAMWON Gaming -> https://gol.gg/teams/team-stats/849/split-ALL/tournament-ALL/
# Scraping roster for team: DragonX -> https://gol.gg/teams/team-stats/853/split-ALL/tournament-ALL/
# Scraping roster for team: ESC Shane -> https://gol.gg/teams/team-stats/862/split-ALL/tournament-ALL/
# Scraping roster for team: Gen.G eSports -> https://gol.gg/teams/team-stats/852/split-ALL/tournament-ALL/
# Scraping roster for team: Griffin -> https://gol.gg/teams/team-stats/848/split-ALL/tournament-ALL/
# Scraping roster for team: Hanwha Life eSports -> https://gol.gg/teams/team-stats/855/split-ALL/tournament-ALL/
# Scraping roster for team: KT Rolster -> https://gol.gg/teams/team-stats/854/split-ALL/tournament-ALL/
# Scraping roster for team: Sandbox Gaming -> https://gol.gg/teams/team-stats/850/split-ALL/tournament-ALL/
# Scraping roster for team: SeolHaeOne Prince -> https://gol.gg/teams/team-stats/858/split-ALL/tournament-ALL/
# Scraping roster for team: T1 -> https://gol.gg/teams/team-stats/847/split-ALL/tournament-ALL/
# Scraping roster for team: Team Dynamics -> https://gol.gg/teams/team-stats/857/split-ALL/tournament-ALL/
# Scraping roster for team: Afreeca Freecs -> https://gol.gg/teams/team-stats/1091/split-ALL/tournament-ALL/
# Scraping roster for team: DRX -> https://gol.gg/teams/team-stats/1093/split-ALL/tournament-ALL/
# Scraping roster for team: DWG KIA -> https://gol.gg/teams/team-stats/1092/split-ALL/tournament-ALL/
# Scraping roster for team: Fredit BRION -> https://gol.gg/teams/team-stats/1094/split-ALL/tournament-ALL/
# Scraping roster for team: Gen.G eSports -> https://gol.gg/teams/team-stats/1126/split-ALL/tournament-ALL/
# Scraping roster for team: Hanwha Life eSports -> https://gol.gg/teams/team-stats/1096/split-ALL/tournament-ALL/
# Scraping roster for team: KT Rolster -> https://gol.gg/teams/team-stats/1097/split-ALL/tournament-ALL/
# Scraping roster for team: Liiv SANDBOX -> https://gol.gg/teams/team-stats/1098/split-ALL/tournament-ALL/
# Scraping roster for team: Nongshim RedForce -> https://gol.gg/teams/team-stats/1099/split-ALL/tournament-ALL/
# Scraping roster for team: T1 -> https://gol.gg/teams/team-stats/1125/split-ALL/tournament-ALL/
# Scraping roster for team: DRX -> https://gol.gg/teams/team-stats/1413/split-ALL/tournament-ALL/
# Scraping roster for team: DWG KIA -> https://gol.gg/teams/team-stats/1412/split-ALL/tournament-ALL/
# Scraping roster for team: Fredit BRION -> https://gol.gg/teams/team-stats/1414/split-ALL/tournament-ALL/
# Scraping roster for team: Gen.G eSports -> https://gol.gg/teams/team-stats/1439/split-ALL/tournament-ALL/
# Scraping roster for team: Hanwha Life eSports -> https://gol.gg/teams/team-stats/1416/split-ALL/tournament-ALL/
# Scraping roster for team: KT Rolster -> https://gol.gg/teams/team-stats/1417/split-ALL/tournament-ALL/
# Scraping roster for team: Kwangdong Freecs -> https://gol.gg/teams/team-stats/1411/split-ALL/tournament-ALL/
# Scraping roster for team: Liiv SANDBOX -> https://gol.gg/teams/team-stats/1418/split-ALL/tournament-ALL/
# Scraping roster for team: Nongshim RedForce -> https://gol.gg/teams/team-stats/1419/split-ALL/tournament-ALL/
# Scraping roster for team: T1 -> https://gol.gg/teams/team-stats/1438/split-ALL/tournament-ALL/
# Scraping roster for team: BRION -> https://gol.gg/teams/team-stats/1767/split-ALL/tournament-ALL/
# Scraping roster for team: Dplus KIA -> https://gol.gg/teams/team-stats/1765/split-ALL/tournament-ALL/
# Scraping roster for team: DRX -> https://gol.gg/teams/team-stats/1766/split-ALL/tournament-ALL/
# Scraping roster for team: Gen.G eSports -> https://gol.gg/teams/team-stats/1792/split-ALL/tournament-ALL/
# Scraping roster for team: Hanwha Life eSports -> https://gol.gg/teams/team-stats/1769/split-ALL/tournament-ALL/
# Scraping roster for team: KT Rolster -> https://gol.gg/teams/team-stats/1770/split-ALL/tournament-ALL/
# Scraping roster for team: Kwangdong Freecs -> https://gol.gg/teams/team-stats/1764/split-ALL/tournament-ALL/
# Scraping roster for team: Liiv SANDBOX -> https://gol.gg/teams/team-stats/1771/split-ALL/tournament-ALL/
# Scraping roster for team: Nongshim RedForce -> https://gol.gg/teams/team-stats/1772/split-ALL/tournament-ALL/
# Scraping roster for team: T1 -> https://gol.gg/teams/team-stats/1791/split-ALL/tournament-ALL/
# Scraping roster for team: Dplus KIA -> https://gol.gg/teams/team-stats/2118/split-ALL/tournament-ALL/
# Scraping roster for team: DRX -> https://gol.gg/teams/team-stats/2119/split-ALL/tournament-ALL/
# Scraping roster for team: FearX -> https://gol.gg/teams/team-stats/2124/split-ALL/tournament-ALL/
# Scraping roster for team: Gen.G eSports -> https://gol.gg/teams/team-stats/2145/split-ALL/tournament-ALL/
# Scraping roster for team: Hanwha Life eSports -> https://gol.gg/teams/team-stats/2122/split-ALL/tournament-ALL/
# Scraping roster for team: KT Rolster -> https://gol.gg/teams/team-stats/2123/split-ALL/tournament-ALL/
# Scraping roster for team: Kwangdong Freecs -> https://gol.gg/teams/team-stats/2117/split-ALL/tournament-ALL/
# Scraping roster for team: Nongshim RedForce -> https://gol.gg/teams/team-stats/2125/split-ALL/tournament-ALL/
# Scraping roster for team: OK BRION -> https://gol.gg/teams/team-stats/2120/split-ALL/tournament-ALL/
# Scraping roster for team: T1 -> https://gol.gg/teams/team-stats/2144/split-ALL/tournament-ALL/

# %%
rows = []
for team_key, roster in team_rosters_dict.items():
    # Use regex to separate team name and season (e.g., "Afreeca Freecs" and "S6")
    match = re.search(r"^(.*)\s+(S\d+)$", team_key)
    if match:
        team_name = match.group(1).strip()
        season = match.group(2).strip()
    else:
        # Fallback if regex doesn't match
        team_name = team_key
        season = None

    # For each player in the roster, create a row dictionary
    for player in roster:
        rows.append({
            "Team": team_name,
            "Season": season,
            "Player": player
        })

# Create the DataFrame from the list of rows
df = pd.DataFrame(rows)
df.to_csv("rosters.csv", index=False)
