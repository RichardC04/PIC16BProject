# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
def get_league_data(player="player", season="ALL", year="S14", role="TOP"):
    website = ""
    if player == "player":
        website = f"https://gol.gg/players/list/season-{year}/split-{season}/tournament-ALL/"
    else:
        website = f"https://gol.gg/teams/list/season-{year}/split-{season}/tournament-ALL/"
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
    driver.get(website)

    extracted_data = {}

    try:
        #Wait a bit for the page to load fully
        time.sleep(3)
        #Type "LCK" into the Leagues input (Selectize control)
        league_input = driver.find_element(By.CSS_SELECTOR, ".selectize-control.multi .selectize-input input")
        league_input.send_keys("LCK")
        time.sleep(1)
        league_input.send_keys(Keys.ENTER)  # finalize selection
        time.sleep(2)

        #Click the "Refresh" button to apply the LCK filter
        refresh_button = driver.find_element(By.ID, "btn_refresh")
        refresh_button.click()
        time.sleep(5)
        if player == "player": #if input is player
            #set the role filter with role input
            hidden_role = driver.find_element(By.ID, "hiddenfieldrole")
            driver.execute_script("arguments[0].value = arguments[1];", hidden_role, role)
    
            #Submit the form again to filter by role
            form = driver.find_element(By.ID, "FilterForm")
            form.submit()
            time.sleep(5)

        #Parse the updated page with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, 'html.parser')

        #Locate the table containing wanted data
        table = soup.select_one("table.table_list.playerslist.tablesaw.trhover.tablesaw-swipe.tablesaw-sortable")
        if table:
            #Extract rows
            rows = table.find_all('tr')
            table_data = []
            for row in rows:
                cells = row.find_all(['td', 'th'])
                cell_texts = [cell.get_text(strip=True) for cell in cells]
                if cell_texts:
                    table_data.append(cell_texts)

            #Build a 2d dict from the table
            if len(table_data) > 1:
                headers = table_data[0]
                for i in range(1, len(table_data)):
                    row_key = table_data[i][0] + " " + year
                    row_dict = {}
                    if player == "player":
                        row_dict["Season"] = year
                    for j in range(1, len(headers)):
                        if j < len(table_data[i]):
                            row_dict[headers[j]] = table_data[i][j]
                    extracted_data[row_key] = row_dict
            else:
                print("No valid data rows found.")
        else:
            print("Could not find the table.")

    finally:
        #Close the browser
        driver.quit()

    return extracted_data

# %%
teams_year = get_league_data("team","ALL", "S14")
teams_year
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 teams_year = get_league_data("team","ALL", "S14")
#       2 teams_year
#
# Cell In[26], line 53, in get_league_data(player, season, year, role)
#      51 #Build a 2d dict from the table
#      52 if len(table_data) > 1:
# ---> 53     headers = table_data[0] + year
#      54     for i in range(1, len(table_data)):
#      55         row_key = table_data[i][0]
#
# TypeError: can only concatenate list (not "str") to list

# %%
def collect_player(season,year):
    roles = ["TOP", "JUNGLE", "MID", "ADC", "SUPPORT"]
    data = []
    for role in roles:
        role_data = get_league_data("player", season, year, role)
        data.append(role_data)
    return data

# %%
player_year = collect_player("ALL","S14")
player_year
# Out:
# [{'Casting': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '3',
#    'Win rate': '0%',
#    'KDA': '1.4',
#    'Avg kills': '2.3',
#    'Avg deaths': '3',
#    'Avg assists': '2',
#    'CSM': '8.2',
#    'GPM': '403',
#    'KP%': '57.9%',
#    'DMG%': '27.2',
#    'DPM': '591',
#    'VSPM': '1.06',
#    'Avg WPM': '0.54',
#    'Avg WCPM': '0.11',
#    'Avg VWPM': '0.26',
#    'GD@15': '964',
#    'CSD@15': '4',
#    'XPD@15': '97',
#    'FB %': '66.7%',
#    'FB Victim': '0%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Clear': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '91',
#    'Win rate': '37.4%',
#    'KDA': '2.5',
#    'Avg kills': '2.4',
#    'Avg deaths': '2.7',
#    'Avg assists': '4.4',
#    'CSM': '8.3',
#    'GPM': '386',
#    'KP%': '57.7%',
#    'DMG%': '21.5',
#    'DPM': '489',
#    'VSPM': '0.97',
#    'Avg WPM': '0.32',
#    'Avg WCPM': '0.21',
#    'Avg VWPM': '0.16',
#    'GD@15': '-92',
#    'CSD@15': '-5',
#    'XPD@15': '-134',
#    'FB %': '9.9%',
#    'FB Victim': '9.9%',
#    'Penta Kills': '0',
#    'Solo Kills': '27',
#    'Season': 'S14'},
#   'DnDn': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '55',
#    'Win rate': '30.9%',
#    'KDA': '1.7',
#    'Avg kills': '1.6',
#    'Avg deaths': '2.8',
#    'Avg assists': '3.1',
#    'CSM': '8.5',
#    'GPM': '377',
#    'KP%': '45.5%',
#    'DMG%': '20.5',
#    'DPM': '434',
#    'VSPM': '1.15',
#    'Avg WPM': '0.55',
#    'Avg WCPM': '0.16',
#    'Avg VWPM': '0.29',
#    'GD@15': '-234',
#    'CSD@15': '-4',
#    'XPD@15': '-149',
#    'FB %': '18.2%',
#    'FB Victim': '14.5%',
#    'Penta Kills': '0',
#    'Solo Kills': '15',
#    'Season': 'S14'},
#   'Doran': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '112',
#    'Win rate': '69.6%',
#    'KDA': '3.2',
#    'Avg kills': '2.5',
#    'Avg deaths': '2.6',
#    'Avg assists': '5.9',
#    'CSM': '8',
#    'GPM': '392',
#    'KP%': '58.1%',
#    'DMG%': '21.8',
#    'DPM': '536',
#    'VSPM': '1.13',
#    'Avg WPM': '0.42',
#    'Avg WCPM': '0.22',
#    'Avg VWPM': '0.21',
#    'GD@15': '114',
#    'CSD@15': '1',
#    'XPD@15': '119',
#    'FB %': '22.3%',
#    'FB Victim': '13.4%',
#    'Penta Kills': '0',
#    'Solo Kills': '27',
#    'Season': 'S14'},
#   'DuDu': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '90',
#    'Win rate': '43.3%',
#    'KDA': '2.8',
#    'Avg kills': '2.5',
#    'Avg deaths': '2.4',
#    'Avg assists': '4',
#    'CSM': '8.9',
#    'GPM': '400',
#    'KP%': '56.6%',
#    'DMG%': '20.9',
#    'DPM': '484',
#    'VSPM': '0.93',
#    'Avg WPM': '0.3',
#    'Avg WCPM': '0.18',
#    'Avg VWPM': '0.14',
#    'GD@15': '29',
#    'CSD@15': '3',
#    'XPD@15': '40',
#    'FB %': '11.1%',
#    'FB Victim': '15.6%',
#    'Penta Kills': '0',
#    'Solo Kills': '22',
#    'Season': 'S14'},
#   'Frog': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '21',
#    'Win rate': '38.1%',
#    'KDA': '2.2',
#    'Avg kills': '1.2',
#    'Avg deaths': '2.7',
#    'Avg assists': '4.6',
#    'CSM': '7.6',
#    'GPM': '343',
#    'KP%': '54.9%',
#    'DMG%': '17.9',
#    'DPM': '380',
#    'VSPM': '0.99',
#    'Avg WPM': '0.4',
#    'Avg WCPM': '0.16',
#    'Avg VWPM': '0.21',
#    'GD@15': '-562',
#    'CSD@15': '-13',
#    'XPD@15': '-324',
#    'FB %': '9.5%',
#    'FB Victim': '19%',
#    'Penta Kills': '0',
#    'Solo Kills': '3',
#    'Season': 'S14'},
#   'Kiin': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '103',
#    'Win rate': '83.5%',
#    'KDA': '4.4',
#    'Avg kills': '2.8',
#    'Avg deaths': '2',
#    'Avg assists': '6',
#    'CSM': '8.1',
#    'GPM': '405',
#    'KP%': '58.4%',
#    'DMG%': '21',
#    'DPM': '554',
#    'VSPM': '1.18',
#    'Avg WPM': '0.42',
#    'Avg WCPM': '0.22',
#    'Avg VWPM': '0.18',
#    'GD@15': '366',
#    'CSD@15': '9',
#    'XPD@15': '292',
#    'FB %': '20.4%',
#    'FB Victim': '11.7%',
#    'Penta Kills': '0',
#    'Solo Kills': '32',
#    'Season': 'S14'},
#   'Mihile': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '29',
#    'Win rate': '34.5%',
#    'KDA': '1.9',
#    'Avg kills': '1.9',
#    'Avg deaths': '3',
#    'Avg assists': '4',
#    'CSM': '8.3',
#    'GPM': '376',
#    'KP%': '54.4%',
#    'DMG%': '19.9',
#    'DPM': '483',
#    'VSPM': '1.09',
#    'Avg WPM': '0.36',
#    'Avg WCPM': '0.23',
#    'Avg VWPM': '0.18',
#    'GD@15': '-462',
#    'CSD@15': '-6',
#    'XPD@15': '-99',
#    'FB %': '6.9%',
#    'FB Victim': '17.2%',
#    'Penta Kills': '0',
#    'Solo Kills': '5',
#    'Season': 'S14'},
#   'Morgan': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '82',
#    'Win rate': '19.5%',
#    'KDA': '1.9',
#    'Avg kills': '2.1',
#    'Avg deaths': '3',
#    'Avg assists': '3.6',
#    'CSM': '8.3',
#    'GPM': '371',
#    'KP%': '57.4%',
#    'DMG%': '22.5',
#    'DPM': '487',
#    'VSPM': '1.07',
#    'Avg WPM': '0.35',
#    'Avg WCPM': '0.24',
#    'Avg VWPM': '0.23',
#    'GD@15': '-175',
#    'CSD@15': '-3',
#    'XPD@15': '-205',
#    'FB %': '17.1%',
#    'FB Victim': '13.4%',
#    'Penta Kills': '0',
#    'Solo Kills': '10',
#    'Season': 'S14'},
#   'PerfecT': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '102',
#    'Win rate': '53.9%',
#    'KDA': '3',
#    'Avg kills': '2.2',
#    'Avg deaths': '2.5',
#    'Avg assists': '5.1',
#    'CSM': '7.8',
#    'GPM': '371',
#    'KP%': '50.5%',
#    'DMG%': '19.5',
#    'DPM': '465',
#    'VSPM': '1.19',
#    'Avg WPM': '0.46',
#    'Avg WCPM': '0.2',
#    'Avg VWPM': '0.25',
#    'GD@15': '-143',
#    'CSD@15': '-2',
#    'XPD@15': '-58',
#    'FB %': '8.8%',
#    'FB Victim': '11.8%',
#    'Penta Kills': '0',
#    'Solo Kills': '22',
#    'Season': 'S14'},
#   'Rascal': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '62',
#    'Win rate': '21%',
#    'KDA': '1.6',
#    'Avg kills': '1.7',
#    'Avg deaths': '2.9',
#    'Avg assists': '2.9',
#    'CSM': '8.2',
#    'GPM': '366',
#    'KP%': '55.1%',
#    'DMG%': '19.4',
#    'DPM': '407',
#    'VSPM': '1.15',
#    'Avg WPM': '0.39',
#    'Avg WCPM': '0.24',
#    'Avg VWPM': '0.19',
#    'GD@15': '-274',
#    'CSD@15': '-10',
#    'XPD@15': '-190',
#    'FB %': '17.7%',
#    'FB Victim': '12.9%',
#    'Penta Kills': '0',
#    'Solo Kills': '9',
#    'Season': 'S14'},
#   'Zeus': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '124',
#    'Win rate': '62.1%',
#    'KDA': '2.9',
#    'Avg kills': '3',
#    'Avg deaths': '2.7',
#    'Avg assists': '4.5',
#    'CSM': '8.5',
#    'GPM': '412',
#    'KP%': '56.5%',
#    'DMG%': '22.5',
#    'DPM': '552',
#    'VSPM': '1.08',
#    'Avg WPM': '0.37',
#    'Avg WCPM': '0.19',
#    'Avg VWPM': '0.17',
#    'GD@15': '332',
#    'CSD@15': '8',
#    'XPD@15': '76',
#    'FB %': '13.7%',
#    'FB Victim': '12.1%',
#    'Penta Kills': '1',
#    'Solo Kills': '44',
#    'Season': 'S14'},
#   'kingen': {'Country': 'KR',
#    'Position': 'TOP',
#    'Games': '116',
#    'Win rate': '53.4%',
#    'KDA': '2.9',
#    'Avg kills': '2.4',
#    'Avg deaths': '2.5',
#    'Avg assists': '4.9',
#    'CSM': '8',
#    'GPM': '385',
#    'KP%': '53%',
#    'DMG%': '22.1',
#    'DPM': '519',
#    'VSPM': '1.15',
#    'Avg WPM': '0.41',
#    'Avg WCPM': '0.23',
#    'Avg VWPM': '0.22',
#    'GD@15': '-41',
#    'CSD@15': '0',
#    'XPD@15': '69',
#    'FB %': '22.4%',
#    'FB Victim': '9.5%',
#    'Penta Kills': '0',
#    'Solo Kills': '25',
#    'Season': 'S14'}},
#  {'Canyon': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '103',
#    'Win rate': '83.5%',
#    'KDA': '6.2',
#    'Avg kills': '2.2',
#    'Avg deaths': '1.8',
#    'Avg assists': '8.9',
#    'CSM': '6.2',
#    'GPM': '359',
#    'KP%': '72.1%',
#    'DMG%': '14.9',
#    'DPM': '400',
#    'VSPM': '1.69',
#    'Avg WPM': '0.5',
#    'Avg WCPM': '0.38',
#    'Avg VWPM': '0.34',
#    'GD@15': '102',
#    'CSD@15': '3',
#    'XPD@15': '197',
#    'FB %': '26.2%',
#    'FB Victim': '7.8%',
#    'Penta Kills': '0',
#    'Solo Kills': '5',
#    'Season': 'S14'},
#   'Cuzz': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '90',
#    'Win rate': '43.3%',
#    'KDA': '2.9',
#    'Avg kills': '1.9',
#    'Avg deaths': '2.8',
#    'Avg assists': '6.3',
#    'CSM': '6.5',
#    'GPM': '341',
#    'KP%': '73.9%',
#    'DMG%': '16.5',
#    'DPM': '394',
#    'VSPM': '1.84',
#    'Avg WPM': '0.43',
#    'Avg WCPM': '0.49',
#    'Avg VWPM': '0.3',
#    'GD@15': '-25',
#    'CSD@15': '3',
#    'XPD@15': '77',
#    'FB %': '24.4%',
#    'FB Victim': '7.8%',
#    'Penta Kills': '0',
#    'Solo Kills': '4',
#    'Season': 'S14'},
#   'DDoiV': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '10',
#    'Win rate': '30%',
#    'KDA': '2.3',
#    'Avg kills': '1.2',
#    'Avg deaths': '2.8',
#    'Avg assists': '5.1',
#    'CSM': '5.5',
#    'GPM': '309',
#    'KP%': '68.6%',
#    'DMG%': '15.7',
#    'DPM': '335',
#    'VSPM': '1.67',
#    'Avg WPM': '0.46',
#    'Avg WCPM': '0.41',
#    'Avg VWPM': '0.38',
#    'GD@15': '-230',
#    'CSD@15': '-8',
#    'XPD@15': '-388',
#    'FB %': '40%',
#    'FB Victim': '10%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'GIDEON': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '37',
#    'Win rate': '21.6%',
#    'KDA': '2.4',
#    'Avg kills': '1.3',
#    'Avg deaths': '2.9',
#    'Avg assists': '5.8',
#    'CSM': '5.6',
#    'GPM': '308',
#    'KP%': '73.2%',
#    'DMG%': '12.9',
#    'DPM': '269',
#    'VSPM': '1.54',
#    'Avg WPM': '0.38',
#    'Avg WCPM': '0.42',
#    'Avg VWPM': '0.32',
#    'GD@15': '-16',
#    'CSD@15': '2',
#    'XPD@15': '88',
#    'FB %': '24.3%',
#    'FB Victim': '10.8%',
#    'Penta Kills': '0',
#    'Solo Kills': '4',
#    'Season': 'S14'},
#   'Guwon': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '2',
#    'Win rate': '100%',
#    'KDA': '7.8',
#    'Avg kills': '4.5',
#    'Avg deaths': '2',
#    'Avg assists': '11',
#    'CSM': '5.5',
#    'GPM': '378',
#    'KP%': '69%',
#    'DMG%': '13.2',
#    'DPM': '382',
#    'VSPM': '1.39',
#    'Avg WPM': '0.34',
#    'Avg WCPM': '0.29',
#    'Avg VWPM': '0.36',
#    'GD@15': '166',
#    'CSD@15': '-12',
#    'XPD@15': '100',
#    'FB %': '100%',
#    'FB Victim': '0%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Lucid': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '116',
#    'Win rate': '53.4%',
#    'KDA': '4.3',
#    'Avg kills': '2',
#    'Avg deaths': '2.3',
#    'Avg assists': '7.7',
#    'CSM': '5.7',
#    'GPM': '333',
#    'KP%': '71.7%',
#    'DMG%': '12.5',
#    'DPM': '297',
#    'VSPM': '1.66',
#    'Avg WPM': '0.5',
#    'Avg WCPM': '0.4',
#    'Avg VWPM': '0.45',
#    'GD@15': '49',
#    'CSD@15': '-3',
#    'XPD@15': '-58',
#    'FB %': '45.7%',
#    'FB Victim': '6%',
#    'Penta Kills': '0',
#    'Solo Kills': '7',
#    'Season': 'S14'},
#   'Oner': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '122',
#    'Win rate': '61.5%',
#    'KDA': '3.8',
#    'Avg kills': '2.4',
#    'Avg deaths': '2.4',
#    'Avg assists': '6.8',
#    'CSM': '6.4',
#    'GPM': '357',
#    'KP%': '68%',
#    'DMG%': '14.9',
#    'DPM': '365',
#    'VSPM': '1.67',
#    'Avg WPM': '0.41',
#    'Avg WCPM': '0.43',
#    'Avg VWPM': '0.28',
#    'GD@15': '80',
#    'CSD@15': '6',
#    'XPD@15': '156',
#    'FB %': '37.7%',
#    'FB Victim': '13.9%',
#    'Penta Kills': '0',
#    'Solo Kills': '15',
#    'Season': 'S14'},
#   'Peanut': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '112',
#    'Win rate': '69.6%',
#    'KDA': '5.3',
#    'Avg kills': '2.2',
#    'Avg deaths': '2',
#    'Avg assists': '8.5',
#    'CSM': '6.1',
#    'GPM': '349',
#    'KP%': '74.6%',
#    'DMG%': '13.3',
#    'DPM': '326',
#    'VSPM': '1.76',
#    'Avg WPM': '0.42',
#    'Avg WCPM': '0.46',
#    'Avg VWPM': '0.28',
#    'GD@15': '132',
#    'CSD@15': '0',
#    'XPD@15': '78',
#    'FB %': '42.9%',
#    'FB Victim': '9.8%',
#    'Penta Kills': '0',
#    'Solo Kills': '8',
#    'Season': 'S14'},
#   'Pyosik': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '105',
#    'Win rate': '52.4%',
#    'KDA': '4.2',
#    'Avg kills': '2.3',
#    'Avg deaths': '2.3',
#    'Avg assists': '7.4',
#    'CSM': '5.8',
#    'GPM': '337',
#    'KP%': '72.6%',
#    'DMG%': '13.4',
#    'DPM': '322',
#    'VSPM': '1.69',
#    'Avg WPM': '0.5',
#    'Avg WCPM': '0.4',
#    'Avg VWPM': '0.37',
#    'GD@15': '-61',
#    'CSD@15': '-3',
#    'XPD@15': '-136',
#    'FB %': '40%',
#    'FB Victim': '6.7%',
#    'Penta Kills': '1',
#    'Solo Kills': '5',
#    'Season': 'S14'},
#   'Raptor': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '48',
#    'Win rate': '37.5%',
#    'KDA': '3',
#    'Avg kills': '2.3',
#    'Avg deaths': '2.9',
#    'Avg assists': '6.2',
#    'CSM': '6.1',
#    'GPM': '341',
#    'KP%': '74.5%',
#    'DMG%': '18.6',
#    'DPM': '448',
#    'VSPM': '1.57',
#    'Avg WPM': '0.35',
#    'Avg WCPM': '0.44',
#    'Avg VWPM': '0.29',
#    'GD@15': '-115',
#    'CSD@15': '-1',
#    'XPD@15': '-68',
#    'FB %': '18.8%',
#    'FB Victim': '12.5%',
#    'Penta Kills': '0',
#    'Solo Kills': '2',
#    'Season': 'S14'},
#   'Sponge': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '83',
#    'Win rate': '25.3%',
#    'KDA': '1.9',
#    'Avg kills': '1.5',
#    'Avg deaths': '3.4',
#    'Avg assists': '4.8',
#    'CSM': '5.8',
#    'GPM': '314',
#    'KP%': '73%',
#    'DMG%': '14.5',
#    'DPM': '308',
#    'VSPM': '1.5',
#    'Avg WPM': '0.4',
#    'Avg WCPM': '0.39',
#    'Avg VWPM': '0.32',
#    'GD@15': '-81',
#    'CSD@15': '-1',
#    'XPD@15': '-133',
#    'FB %': '34.9%',
#    'FB Victim': '9.6%',
#    'Penta Kills': '0',
#    'Solo Kills': '4',
#    'Season': 'S14'},
#   'Sylvie': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '84',
#    'Win rate': '32.1%',
#    'KDA': '2.4',
#    'Avg kills': '1.6',
#    'Avg deaths': '2.9',
#    'Avg assists': '5.5',
#    'CSM': '5.7',
#    'GPM': '318',
#    'KP%': '72%',
#    'DMG%': '14.1',
#    'DPM': '317',
#    'VSPM': '1.63',
#    'Avg WPM': '0.45',
#    'Avg WCPM': '0.4',
#    'Avg VWPM': '0.39',
#    'GD@15': '-170',
#    'CSD@15': '-6',
#    'XPD@15': '-176',
#    'FB %': '33.3%',
#    'FB Victim': '6%',
#    'Penta Kills': '0',
#    'Solo Kills': '6',
#    'Season': 'S14'},
#   'Willer': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '43',
#    'Win rate': '37.2%',
#    'KDA': '3.4',
#    'Avg kills': '2.4',
#    'Avg deaths': '2.4',
#    'Avg assists': '5.8',
#    'CSM': '6.1',
#    'GPM': '337',
#    'KP%': '70.4%',
#    'DMG%': '15',
#    'DPM': '320',
#    'VSPM': '1.9',
#    'Avg WPM': '0.56',
#    'Avg WCPM': '0.51',
#    'Avg VWPM': '0.43',
#    'GD@15': '162',
#    'CSD@15': '5',
#    'XPD@15': '145',
#    'FB %': '37.2%',
#    'FB Victim': '2.3%',
#    'Penta Kills': '0',
#    'Solo Kills': '5',
#    'Season': 'S14'},
#   'YoungJae': {'Country': 'KR',
#    'Position': 'JUNGLE',
#    'Games': '35',
#    'Win rate': '14.3%',
#    'KDA': '3.2',
#    'Avg kills': '2',
#    'Avg deaths': '2.4',
#    'Avg assists': '5.9',
#    'CSM': '6.3',
#    'GPM': '331',
#    'KP%': '75%',
#    'DMG%': '19',
#    'DPM': '426',
#    'VSPM': '1.81',
#    'Avg WPM': '0.58',
#    'Avg WCPM': '0.41',
#    'Avg VWPM': '0.38',
#    'GD@15': '-288',
#    'CSD@15': '-7',
#    'XPD@15': '-306',
#    'FB %': '31.4%',
#    'FB Victim': '5.7%',
#    'Penta Kills': '0',
#    'Solo Kills': '2',
#    'Season': 'S14'}},
#  {'Bdd': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '105',
#    'Win rate': '52.4%',
#    'KDA': '4.7',
#    'Avg kills': '3.9',
#    'Avg deaths': '2.1',
#    'Avg assists': '6',
#    'CSM': '9.1',
#    'GPM': '419',
#    'KP%': '70.7%',
#    'DMG%': '28.6',
#    'DPM': '677',
#    'VSPM': '1.19',
#    'Avg WPM': '0.44',
#    'Avg WCPM': '0.25',
#    'Avg VWPM': '0.22',
#    'GD@15': '49',
#    'CSD@15': '1',
#    'XPD@15': '4',
#    'FB %': '20%',
#    'FB Victim': '8.6%',
#    'Penta Kills': '1',
#    'Solo Kills': '15',
#    'Season': 'S14'},
#   'Bulldog': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '90',
#    'Win rate': '43.3%',
#    'KDA': '3',
#    'Avg kills': '2.8',
#    'Avg deaths': '2.5',
#    'Avg assists': '4.6',
#    'CSM': '9.3',
#    'GPM': '416',
#    'KP%': '68.8%',
#    'DMG%': '28.8',
#    'DPM': '669',
#    'VSPM': '1.35',
#    'Avg WPM': '0.49',
#    'Avg WCPM': '0.29',
#    'Avg VWPM': '0.23',
#    'GD@15': '-188',
#    'CSD@15': '-4',
#    'XPD@15': '-89',
#    'FB %': '14.4%',
#    'FB Victim': '12.2%',
#    'Penta Kills': '1',
#    'Solo Kills': '8',
#    'Season': 'S14'},
#   'Calix': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '8',
#    'Win rate': '25%',
#    'KDA': '1.7',
#    'Avg kills': '1.6',
#    'Avg deaths': '2.8',
#    'Avg assists': '3.1',
#    'CSM': '9',
#    'GPM': '377',
#    'KP%': '63.3%',
#    'DMG%': '23.9',
#    'DPM': '548',
#    'VSPM': '0.77',
#    'Avg WPM': '0.35',
#    'Avg WCPM': '0.14',
#    'Avg VWPM': '0.15',
#    'GD@15': '-593',
#    'CSD@15': '-11',
#    'XPD@15': '-280',
#    'FB %': '25%',
#    'FB Victim': '0%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Callme': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '36',
#    'Win rate': '33.3%',
#    'KDA': '2.1',
#    'Avg kills': '2.3',
#    'Avg deaths': '3.4',
#    'Avg assists': '4.7',
#    'CSM': '9',
#    'GPM': '400',
#    'KP%': '72.5%',
#    'DMG%': '29.2',
#    'DPM': '617',
#    'VSPM': '1.29',
#    'Avg WPM': '0.41',
#    'Avg WCPM': '0.33',
#    'Avg VWPM': '0.21',
#    'GD@15': '-132',
#    'CSD@15': '-5',
#    'XPD@15': '-12',
#    'FB %': '19.4%',
#    'FB Victim': '19.4%',
#    'Penta Kills': '0',
#    'Solo Kills': '5',
#    'Season': 'S14'},
#   'Chovy': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '103',
#    'Win rate': '83.5%',
#    'KDA': '6.2',
#    'Avg kills': '4.5',
#    'Avg deaths': '1.7',
#    'Avg assists': '5.8',
#    'CSM': '10.3',
#    'GPM': '483',
#    'KP%': '67.1%',
#    'DMG%': '29.9',
#    'DPM': '801',
#    'VSPM': '1.71',
#    'Avg WPM': '0.5',
#    'Avg WCPM': '0.49',
#    'Avg VWPM': '0.18',
#    'GD@15': '410',
#    'CSD@15': '10',
#    'XPD@15': '296',
#    'FB %': '9.7%',
#    'FB Victim': '7.8%',
#    'Penta Kills': '0',
#    'Solo Kills': '24',
#    'Season': 'S14'},
#   'Clozer': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '91',
#    'Win rate': '37.4%',
#    'KDA': '3.3',
#    'Avg kills': '2.8',
#    'Avg deaths': '2.4',
#    'Avg assists': '4.9',
#    'CSM': '9.9',
#    'GPM': '424',
#    'KP%': '65.6%',
#    'DMG%': '27.3',
#    'DPM': '616',
#    'VSPM': '1.23',
#    'Avg WPM': '0.49',
#    'Avg WCPM': '0.29',
#    'Avg VWPM': '0.19',
#    'GD@15': '-114',
#    'CSD@15': '2',
#    'XPD@15': '59',
#    'FB %': '20.9%',
#    'FB Victim': '11%',
#    'Penta Kills': '0',
#    'Solo Kills': '18',
#    'Season': 'S14'},
#   'FATE': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '19',
#    'Win rate': '21.1%',
#    'KDA': '2.9',
#    'Avg kills': '2.3',
#    'Avg deaths': '2.3',
#    'Avg assists': '4.2',
#    'CSM': '9',
#    'GPM': '402',
#    'KP%': '62.9%',
#    'DMG%': '28.4',
#    'DPM': '627',
#    'VSPM': '1.18',
#    'Avg WPM': '0.42',
#    'Avg WCPM': '0.27',
#    'Avg VWPM': '0.17',
#    'GD@15': '-51',
#    'CSD@15': '-5',
#    'XPD@15': '-89',
#    'FB %': '31.6%',
#    'FB Victim': '0%',
#    'Penta Kills': '1',
#    'Solo Kills': '2',
#    'Season': 'S14'},
#   'FIESTA': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '7',
#    'Win rate': '14.3%',
#    'KDA': '2.6',
#    'Avg kills': '3.3',
#    'Avg deaths': '3',
#    'Avg assists': '4.6',
#    'CSM': '8.3',
#    'GPM': '392',
#    'KP%': '65%',
#    'DMG%': '28',
#    'DPM': '599',
#    'VSPM': '1.55',
#    'Avg WPM': '0.68',
#    'Avg WCPM': '0.37',
#    'Avg VWPM': '0.33',
#    'GD@15': '-38',
#    'CSD@15': '-3',
#    'XPD@15': '-143',
#    'FB %': '42.9%',
#    'FB Victim': '0%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Faker': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '124',
#    'Win rate': '62.1%',
#    'KDA': '4',
#    'Avg kills': '3.3',
#    'Avg deaths': '2.2',
#    'Avg assists': '5.5',
#    'CSM': '9.2',
#    'GPM': '429',
#    'KP%': '63.8%',
#    'DMG%': '26.3',
#    'DPM': '642',
#    'VSPM': '1.23',
#    'Avg WPM': '0.45',
#    'Avg WCPM': '0.26',
#    'Avg VWPM': '0.14',
#    'GD@15': '62',
#    'CSD@15': '1',
#    'XPD@15': '5',
#    'FB %': '21.8%',
#    'FB Victim': '6.5%',
#    'Penta Kills': '0',
#    'Solo Kills': '28',
#    'Season': 'S14'},
#   'Fisher': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '33',
#    'Win rate': '36.4%',
#    'KDA': '2.6',
#    'Avg kills': '3.4',
#    'Avg deaths': '2.9',
#    'Avg assists': '4.2',
#    'CSM': '9.4',
#    'GPM': '425',
#    'KP%': '65.7%',
#    'DMG%': '29.6',
#    'DPM': '690',
#    'VSPM': '1.1',
#    'Avg WPM': '0.45',
#    'Avg WCPM': '0.24',
#    'Avg VWPM': '0.21',
#    'GD@15': '-29',
#    'CSD@15': '-1',
#    'XPD@15': '-60',
#    'FB %': '18.2%',
#    'FB Victim': '18.2%',
#    'Penta Kills': '0',
#    'Solo Kills': '4',
#    'Season': 'S14'},
#   'Karis': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '57',
#    'Win rate': '19.3%',
#    'KDA': '2.2',
#    'Avg kills': '2.1',
#    'Avg deaths': '2.8',
#    'Avg assists': '4.2',
#    'CSM': '9.1',
#    'GPM': '394',
#    'KP%': '66.2%',
#    'DMG%': '26',
#    'DPM': '543',
#    'VSPM': '1.07',
#    'Avg WPM': '0.32',
#    'Avg WCPM': '0.29',
#    'Avg VWPM': '0.2',
#    'GD@15': '-268',
#    'CSD@15': '-2',
#    'XPD@15': '-91',
#    'FB %': '15.8%',
#    'FB Victim': '10.5%',
#    'Penta Kills': '0',
#    'Solo Kills': '7',
#    'Season': 'S14'},
#   'Kyeahoo': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '49',
#    'Win rate': '28.6%',
#    'KDA': '2.9',
#    'Avg kills': '2.1',
#    'Avg deaths': '2.2',
#    'Avg assists': '4.4',
#    'CSM': '9',
#    'GPM': '394',
#    'KP%': '68.7%',
#    'DMG%': '28.2',
#    'DPM': '590',
#    'VSPM': '1.12',
#    'Avg WPM': '0.41',
#    'Avg WCPM': '0.25',
#    'Avg VWPM': '0.18',
#    'GD@15': '-212',
#    'CSD@15': '-6',
#    'XPD@15': '-220',
#    'FB %': '20.4%',
#    'FB Victim': '16.3%',
#    'Penta Kills': '0',
#    'Solo Kills': '3',
#    'Season': 'S14'},
#   'Pullbae': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '6',
#    'Win rate': '16.7%',
#    'KDA': '2.2',
#    'Avg kills': '2.5',
#    'Avg deaths': '4',
#    'Avg assists': '6.2',
#    'CSM': '8.4',
#    'GPM': '386',
#    'KP%': '72.2%',
#    'DMG%': '26.3',
#    'DPM': '685',
#    'VSPM': '1.23',
#    'Avg WPM': '0.54',
#    'Avg WCPM': '0.28',
#    'Avg VWPM': '0.21',
#    'GD@15': '-818',
#    'CSD@15': '-9',
#    'XPD@15': '-659',
#    'FB %': '16.7%',
#    'FB Victim': '33.3%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'SeTab': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '34',
#    'Win rate': '20.6%',
#    'KDA': '1.9',
#    'Avg kills': '2.1',
#    'Avg deaths': '2.8',
#    'Avg assists': '3.2',
#    'CSM': '8.9',
#    'GPM': '394',
#    'KP%': '65.1%',
#    'DMG%': '27.1',
#    'DPM': '571',
#    'VSPM': '1.12',
#    'Avg WPM': '0.4',
#    'Avg WCPM': '0.3',
#    'Avg VWPM': '0.18',
#    'GD@15': '-300',
#    'CSD@15': '-6',
#    'XPD@15': '-220',
#    'FB %': '26.5%',
#    'FB Victim': '14.7%',
#    'Penta Kills': '0',
#    'Solo Kills': '5',
#    'Season': 'S14'},
#   'ShowMaker': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '116',
#    'Win rate': '53.4%',
#    'KDA': '4.2',
#    'Avg kills': '3.5',
#    'Avg deaths': '2.1',
#    'Avg assists': '5.5',
#    'CSM': '8.8',
#    'GPM': '416',
#    'KP%': '67.4%',
#    'DMG%': '27.4',
#    'DPM': '644',
#    'VSPM': '1.39',
#    'Avg WPM': '0.5',
#    'Avg WCPM': '0.31',
#    'Avg VWPM': '0.22',
#    'GD@15': '8',
#    'CSD@15': '-2',
#    'XPD@15': '20',
#    'FB %': '25%',
#    'FB Victim': '8.6%',
#    'Penta Kills': '2',
#    'Solo Kills': '24',
#    'Season': 'S14'},
#   'Zeka': {'Country': 'KR',
#    'Position': 'MID',
#    'Games': '112',
#    'Win rate': '69.6%',
#    'KDA': '6',
#    'Avg kills': '4.4',
#    'Avg deaths': '1.7',
#    'Avg assists': '5.6',
#    'CSM': '9.5',
#    'GPM': '447',
#    'KP%': '67.6%',
#    'DMG%': '27.5',
#    'DPM': '669',
#    'VSPM': '1.39',
#    'Avg WPM': '0.53',
#    'Avg WCPM': '0.32',
#    'Avg VWPM': '0.22',
#    'GD@15': '212',
#    'CSD@15': '2',
#    'XPD@15': '32',
#    'FB %': '25.9%',
#    'FB Victim': '4.5%',
#    'Penta Kills': '0',
#    'Solo Kills': '27',
#    'Season': 'S14'}},
#  {'Aiming': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '116',
#    'Win rate': '53.4%',
#    'KDA': '6.6',
#    'Avg kills': '5',
#    'Avg deaths': '1.5',
#    'Avg assists': '4.8',
#    'CSM': '10',
#    'GPM': '471',
#    'KP%': '71%',
#    'DMG%': '30.1',
#    'DPM': '719',
#    'VSPM': '1.52',
#    'Avg WPM': '0.5',
#    'Avg WCPM': '0.49',
#    'Avg VWPM': '0.1',
#    'GD@15': '378',
#    'CSD@15': '8',
#    'XPD@15': '314',
#    'FB %': '26.7%',
#    'FB Victim': '2.6%',
#    'Penta Kills': '2',
#    'Solo Kills': '10',
#    'Season': 'S14'},
#   'Bull': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '42',
#    'Win rate': '42.9%',
#    'KDA': '2.9',
#    'Avg kills': '3.5',
#    'Avg deaths': '3',
#    'Avg assists': '5.1',
#    'CSM': '8.1',
#    'GPM': '395',
#    'KP%': '70.7%',
#    'DMG%': '22.8',
#    'DPM': '528',
#    'VSPM': '1.4',
#    'Avg WPM': '0.64',
#    'Avg WCPM': '0.34',
#    'Avg VWPM': '0.21',
#    'GD@15': '-374',
#    'CSD@15': '-4',
#    'XPD@15': '-124',
#    'FB %': '21.4%',
#    'FB Victim': '11.9%',
#    'Penta Kills': '0',
#    'Solo Kills': '2',
#    'Season': 'S14'},
#   'Deft': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '105',
#    'Win rate': '52.4%',
#    'KDA': '4.5',
#    'Avg kills': '3.8',
#    'Avg deaths': '2.2',
#    'Avg assists': '5.8',
#    'CSM': '8.8',
#    'GPM': '426',
#    'KP%': '69.8%',
#    'DMG%': '29',
#    'DPM': '695',
#    'VSPM': '1.59',
#    'Avg WPM': '0.65',
#    'Avg WCPM': '0.36',
#    'Avg VWPM': '0.18',
#    'GD@15': '86',
#    'CSD@15': '1',
#    'XPD@15': '-38',
#    'FB %': '28.6%',
#    'FB Victim': '8.6%',
#    'Penta Kills': '1',
#    'Solo Kills': '7',
#    'Season': 'S14'},
#   'Envyy': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '64',
#    'Win rate': '21.9%',
#    'KDA': '2.1',
#    'Avg kills': '3',
#    'Avg deaths': '3',
#    'Avg assists': '3.3',
#    'CSM': '9.1',
#    'GPM': '398',
#    'KP%': '63.1%',
#    'DMG%': '28.3',
#    'DPM': '615',
#    'VSPM': '1.19',
#    'Avg WPM': '0.44',
#    'Avg WCPM': '0.36',
#    'Avg VWPM': '0.16',
#    'GD@15': '-380',
#    'CSD@15': '6',
#    'XPD@15': '12',
#    'FB %': '21.9%',
#    'FB Victim': '12.5%',
#    'Penta Kills': '0',
#    'Solo Kills': '5',
#    'Season': 'S14'},
#   'Gumayusi': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '124',
#    'Win rate': '62.1%',
#    'KDA': '4.4',
#    'Avg kills': '3.6',
#    'Avg deaths': '2.1',
#    'Avg assists': '5.6',
#    'CSM': '8.8',
#    'GPM': '436',
#    'KP%': '65.6%',
#    'DMG%': '25.9',
#    'DPM': '640',
#    'VSPM': '1.68',
#    'Avg WPM': '0.65',
#    'Avg WCPM': '0.43',
#    'Avg VWPM': '0.19',
#    'GD@15': '101',
#    'CSD@15': '-6',
#    'XPD@15': '-139',
#    'FB %': '25%',
#    'FB Victim': '8.1%',
#    'Penta Kills': '0',
#    'Solo Kills': '6',
#    'Season': 'S14'},
#   'Hena': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '91',
#    'Win rate': '37.4%',
#    'KDA': '3.7',
#    'Avg kills': '3.5',
#    'Avg deaths': '2.3',
#    'Avg assists': '5',
#    'CSM': '8.9',
#    'GPM': '414',
#    'KP%': '74.2%',
#    'DMG%': '27.4',
#    'DPM': '621',
#    'VSPM': '1.55',
#    'Avg WPM': '0.64',
#    'Avg WCPM': '0.38',
#    'Avg VWPM': '0.18',
#    'GD@15': '-278',
#    'CSD@15': '-8',
#    'XPD@15': '-118',
#    'FB %': '27.5%',
#    'FB Victim': '4.4%',
#    'Penta Kills': '0',
#    'Solo Kills': '8',
#    'Season': 'S14'},
#   'Jiwoo': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '84',
#    'Win rate': '32.1%',
#    'KDA': '2.7',
#    'Avg kills': '3.4',
#    'Avg deaths': '2.6',
#    'Avg assists': '3.6',
#    'CSM': '9',
#    'GPM': '412',
#    'KP%': '68.4%',
#    'DMG%': '29.5',
#    'DPM': '662',
#    'VSPM': '1.37',
#    'Avg WPM': '0.52',
#    'Avg WCPM': '0.39',
#    'Avg VWPM': '0.13',
#    'GD@15': '-232',
#    'CSD@15': '-3',
#    'XPD@15': '-95',
#    'FB %': '21.4%',
#    'FB Victim': '8.3%',
#    'Penta Kills': '0',
#    'Solo Kills': '12',
#    'Season': 'S14'},
#   'Leaper': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '44',
#    'Win rate': '47.7%',
#    'KDA': '2.9',
#    'Avg kills': '2.9',
#    'Avg deaths': '2.3',
#    'Avg assists': '4',
#    'CSM': '9.6',
#    'GPM': '423',
#    'KP%': '66.8%',
#    'DMG%': '26.5',
#    'DPM': '639',
#    'VSPM': '1.11',
#    'Avg WPM': '0.35',
#    'Avg WCPM': '0.35',
#    'Avg VWPM': '0.09',
#    'GD@15': '-508',
#    'CSD@15': '-6',
#    'XPD@15': '-228',
#    'FB %': '13.6%',
#    'FB Victim': '9.1%',
#    'Penta Kills': '1',
#    'Solo Kills': '4',
#    'Season': 'S14'},
#   'Paduck': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '2',
#    'Win rate': '0%',
#    'KDA': '2',
#    'Avg kills': '1',
#    'Avg deaths': '1.5',
#    'Avg assists': '2',
#    'CSM': '8.8',
#    'GPM': '358',
#    'KP%': '43.8%',
#    'DMG%': '21.9',
#    'DPM': '419',
#    'VSPM': '1.32',
#    'Avg WPM': '0.55',
#    'Avg WCPM': '0.36',
#    'Avg VWPM': '0.2',
#    'GD@15': '-202',
#    'CSD@15': '-2',
#    'XPD@15': '-166',
#    'FB %': '0%',
#    'FB Victim': '0%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Peyz': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '103',
#    'Win rate': '83.5%',
#    'KDA': '8',
#    'Avg kills': '5',
#    'Avg deaths': '1.4',
#    'Avg assists': '6.3',
#    'CSM': '9',
#    'GPM': '461',
#    'KP%': '72.9%',
#    'DMG%': '27.3',
#    'DPM': '732',
#    'VSPM': '1.63',
#    'Avg WPM': '0.62',
#    'Avg WCPM': '0.43',
#    'Avg VWPM': '0.15',
#    'GD@15': '177',
#    'CSD@15': '-3',
#    'XPD@15': '87',
#    'FB %': '24.3%',
#    'FB Victim': '5.8%',
#    'Penta Kills': '2',
#    'Solo Kills': '14',
#    'Season': 'S14'},
#   'Samver': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '18',
#    'Win rate': '11.1%',
#    'KDA': '2.7',
#    'Avg kills': '3.1',
#    'Avg deaths': '2.5',
#    'Avg assists': '3.7',
#    'CSM': '8.9',
#    'GPM': '394',
#    'KP%': '64.4%',
#    'DMG%': '24.9',
#    'DPM': '543',
#    'VSPM': '1.26',
#    'Avg WPM': '0.46',
#    'Avg WCPM': '0.32',
#    'Avg VWPM': '0.15',
#    'GD@15': '-173',
#    'CSD@15': '5',
#    'XPD@15': '87',
#    'FB %': '16.7%',
#    'FB Victim': '0%',
#    'Penta Kills': '0',
#    'Solo Kills': '1',
#    'Season': 'S14'},
#   'Taeyoon': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '4',
#    'Win rate': '0%',
#    'KDA': '0.7',
#    'Avg kills': '2',
#    'Avg deaths': '5',
#    'Avg assists': '1.5',
#    'CSM': '8.8',
#    'GPM': '377',
#    'KP%': '42.4%',
#    'DMG%': '27.9',
#    'DPM': '609',
#    'VSPM': '1.14',
#    'Avg WPM': '0.41',
#    'Avg WCPM': '0.45',
#    'Avg VWPM': '0.13',
#    'GD@15': '-308',
#    'CSD@15': '8',
#    'XPD@15': '-111',
#    'FB %': '0%',
#    'FB Victim': '25%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Teddy': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '81',
#    'Win rate': '25.9%',
#    'KDA': '2.9',
#    'Avg kills': '3.1',
#    'Avg deaths': '2.3',
#    'Avg assists': '3.4',
#    'CSM': '9.2',
#    'GPM': '410',
#    'KP%': '72.4%',
#    'DMG%': '30.6',
#    'DPM': '662',
#    'VSPM': '1.46',
#    'Avg WPM': '0.55',
#    'Avg WCPM': '0.41',
#    'Avg VWPM': '0.13',
#    'GD@15': '6',
#    'CSD@15': '7',
#    'XPD@15': '26',
#    'FB %': '23.5%',
#    'FB Victim': '7.4%',
#    'Penta Kills': '0',
#    'Solo Kills': '8',
#    'Season': 'S14'},
#   'Viper': {'Country': 'KR',
#    'Position': 'ADC',
#    'Games': '112',
#    'Win rate': '69.6%',
#    'KDA': '6.8',
#    'Avg kills': '4.6',
#    'Avg deaths': '1.5',
#    'Avg assists': '5.9',
#    'CSM': '9.6',
#    'GPM': '450',
#    'KP%': '71.7%',
#    'DMG%': '30.5',
#    'DPM': '750',
#    'VSPM': '1.65',
#    'Avg WPM': '0.59',
#    'Avg WCPM': '0.46',
#    'Avg VWPM': '0.16',
#    'GD@15': '248',
#    'CSD@15': '4',
#    'XPD@15': '54',
#    'FB %': '22.3%',
#    'FB Victim': '8%',
#    'Penta Kills': '0',
#    'Solo Kills': '13',
#    'Season': 'S14'}},
#  {'Andil': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '76',
#    'Win rate': '46.1%',
#    'KDA': '2.2',
#    'Avg kills': '0.5',
#    'Avg deaths': '3.7',
#    'Avg assists': '7.8',
#    'CSM': '1.4',
#    'GPM': '246',
#    'KP%': '73.9%',
#    'DMG%': '8.5',
#    'DPM': '201',
#    'VSPM': '3.15',
#    'Avg WPM': '1.64',
#    'Avg WCPM': '0.42',
#    'Avg VWPM': '0.36',
#    'GD@15': '-181',
#    'CSD@15': '-4',
#    'XPD@15': '-146',
#    'FB %': '25%',
#    'FB Victim': '17.1%',
#    'Penta Kills': '0',
#    'Solo Kills': '1',
#    'Season': 'S14'},
#   'BeryL': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '105',
#    'Win rate': '52.4%',
#    'KDA': '3.3',
#    'Avg kills': '1.1',
#    'Avg deaths': '3',
#    'Avg assists': '8.7',
#    'CSM': '1.9',
#    'GPM': '266',
#    'KP%': '72.6%',
#    'DMG%': '9.3',
#    'DPM': '220',
#    'VSPM': '3.29',
#    'Avg WPM': '1.62',
#    'Avg WCPM': '0.51',
#    'Avg VWPM': '0.49',
#    'GD@15': '197',
#    'CSD@15': '7',
#    'XPD@15': '275',
#    'FB %': '28.6%',
#    'FB Victim': '14.3%',
#    'Penta Kills': '0',
#    'Solo Kills': '4',
#    'Season': 'S14'},
#   'Delight': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '112',
#    'Win rate': '69.6%',
#    'KDA': '4.8',
#    'Avg kills': '0.8',
#    'Avg deaths': '2.2',
#    'Avg assists': '10',
#    'CSM': '1.6',
#    'GPM': '265',
#    'KP%': '74.5%',
#    'DMG%': '6.9',
#    'DPM': '165',
#    'VSPM': '3.42',
#    'Avg WPM': '1.77',
#    'Avg WCPM': '0.45',
#    'Avg VWPM': '0.45',
#    'GD@15': '96',
#    'CSD@15': '1',
#    'XPD@15': '222',
#    'FB %': '30.4%',
#    'FB Victim': '7.1%',
#    'Penta Kills': '0',
#    'Solo Kills': '3',
#    'Season': 'S14'},
#   'Duro': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '37',
#    'Win rate': '43.2%',
#    'KDA': '2.6',
#    'Avg kills': '0.4',
#    'Avg deaths': '3.1',
#    'Avg assists': '7.7',
#    'CSM': '1.3',
#    'GPM': '243',
#    'KP%': '67.6%',
#    'DMG%': '5.7',
#    'DPM': '131',
#    'VSPM': '3.56',
#    'Avg WPM': '1.94',
#    'Avg WCPM': '0.41',
#    'Avg VWPM': '0.57',
#    'GD@15': '-41',
#    'CSD@15': '2',
#    'XPD@15': '-66',
#    'FB %': '27%',
#    'FB Victim': '18.9%',
#    'Penta Kills': '0',
#    'Solo Kills': '1',
#    'Season': 'S14'},
#   'Effort': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '14',
#    'Win rate': '7.1%',
#    'KDA': '1.5',
#    'Avg kills': '0.2',
#    'Avg deaths': '3.3',
#    'Avg assists': '4.9',
#    'CSM': '1.4',
#    'GPM': '241',
#    'KP%': '84.1%',
#    'DMG%': '8.3',
#    'DPM': '152',
#    'VSPM': '4.16',
#    'Avg WPM': '2.28',
#    'Avg WCPM': '0.69',
#    'Avg VWPM': '0.66',
#    'GD@15': '-469',
#    'CSD@15': '-25',
#    'XPD@15': '-723',
#    'FB %': '21.4%',
#    'FB Victim': '14.3%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Execute': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '54',
#    'Win rate': '33.3%',
#    'KDA': '2.2',
#    'Avg kills': '0.5',
#    'Avg deaths': '3.7',
#    'Avg assists': '7.8',
#    'CSM': '1.2',
#    'GPM': '241',
#    'KP%': '72.2%',
#    'DMG%': '7.7',
#    'DPM': '168',
#    'VSPM': '3.34',
#    'Avg WPM': '2.01',
#    'Avg WCPM': '0.35',
#    'Avg VWPM': '0.52',
#    'GD@15': '-136',
#    'CSD@15': '-7',
#    'XPD@15': '-225',
#    'FB %': '40.7%',
#    'FB Victim': '16.7%',
#    'Penta Kills': '0',
#    'Solo Kills': '1',
#    'Season': 'S14'},
#   'GuGer': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '29',
#    'Win rate': '27.6%',
#    'KDA': '1.6',
#    'Avg kills': '0.6',
#    'Avg deaths': '3.8',
#    'Avg assists': '5.5',
#    'CSM': '1.8',
#    'GPM': '239',
#    'KP%': '66.4%',
#    'DMG%': '7.2',
#    'DPM': '172',
#    'VSPM': '3.15',
#    'Avg WPM': '1.67',
#    'Avg WCPM': '0.4',
#    'Avg VWPM': '0.45',
#    'GD@15': '-281',
#    'CSD@15': '2',
#    'XPD@15': '-153',
#    'FB %': '20.7%',
#    'FB Victim': '10.3%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Kellin': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '90',
#    'Win rate': '52.2%',
#    'KDA': '3.6',
#    'Avg kills': '0.6',
#    'Avg deaths': '2.6',
#    'Avg assists': '8.9',
#    'CSM': '1.3',
#    'GPM': '252',
#    'KP%': '71.8%',
#    'DMG%': '8.5',
#    'DPM': '193',
#    'VSPM': '3.48',
#    'Avg WPM': '1.96',
#    'Avg WCPM': '0.41',
#    'Avg VWPM': '0.46',
#    'GD@15': '-33',
#    'CSD@15': '-5',
#    'XPD@15': '-231',
#    'FB %': '34.4%',
#    'FB Victim': '8.9%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Keria': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '124',
#    'Win rate': '62.1%',
#    'KDA': '4.2',
#    'Avg kills': '1',
#    'Avg deaths': '2.3',
#    'Avg assists': '8.5',
#    'CSM': '2.2',
#    'GPM': '278',
#    'KP%': '69.7%',
#    'DMG%': '10.4',
#    'DPM': '257',
#    'VSPM': '3.21',
#    'Avg WPM': '1.81',
#    'Avg WCPM': '0.39',
#    'Avg VWPM': '0.49',
#    'GD@15': '421',
#    'CSD@15': '13',
#    'XPD@15': '498',
#    'FB %': '28.2%',
#    'FB Victim': '6.5%',
#    'Penta Kills': '0',
#    'Solo Kills': '11',
#    'Season': 'S14'},
#   'Lehends': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '103',
#    'Win rate': '83.5%',
#    'KDA': '4.3',
#    'Avg kills': '0.7',
#    'Avg deaths': '2.5',
#    'Avg assists': '10.1',
#    'CSM': '1.7',
#    'GPM': '271',
#    'KP%': '69.5%',
#    'DMG%': '7',
#    'DPM': '184',
#    'VSPM': '3.28',
#    'Avg WPM': '1.84',
#    'Avg WCPM': '0.37',
#    'Avg VWPM': '0.53',
#    'GD@15': '130',
#    'CSD@15': '7',
#    'XPD@15': '78',
#    'FB %': '28.2%',
#    'FB Victim': '22.3%',
#    'Penta Kills': '0',
#    'Solo Kills': '4',
#    'Season': 'S14'},
#   'Moham': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '26',
#    'Win rate': '57.7%',
#    'KDA': '2.7',
#    'Avg kills': '0.4',
#    'Avg deaths': '3.8',
#    'Avg assists': '9.8',
#    'CSM': '1',
#    'GPM': '244',
#    'KP%': '70.1%',
#    'DMG%': '6.3',
#    'DPM': '148',
#    'VSPM': '3.75',
#    'Avg WPM': '1.9',
#    'Avg WCPM': '0.52',
#    'Avg VWPM': '0.59',
#    'GD@15': '-245',
#    'CSD@15': '4',
#    'XPD@15': '-247',
#    'FB %': '19.2%',
#    'FB Victim': '19.2%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Peter': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '44',
#    'Win rate': '31.8%',
#    'KDA': '3.3',
#    'Avg kills': '0.5',
#    'Avg deaths': '2.3',
#    'Avg assists': '7',
#    'CSM': '1.4',
#    'GPM': '245',
#    'KP%': '75.1%',
#    'DMG%': '7.1',
#    'DPM': '150',
#    'VSPM': '3.32',
#    'Avg WPM': '1.86',
#    'Avg WCPM': '0.41',
#    'Avg VWPM': '0.47',
#    'GD@15': '-269',
#    'CSD@15': '-11',
#    'XPD@15': '-236',
#    'FB %': '25%',
#    'FB Victim': '6.8%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Pleata': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '83',
#    'Win rate': '25.3%',
#    'KDA': '2.4',
#    'Avg kills': '0.5',
#    'Avg deaths': '2.6',
#    'Avg assists': '5.8',
#    'CSM': '1.6',
#    'GPM': '238',
#    'KP%': '72.9%',
#    'DMG%': '8.4',
#    'DPM': '172',
#    'VSPM': '3.44',
#    'Avg WPM': '2.01',
#    'Avg WCPM': '0.45',
#    'Avg VWPM': '0.51',
#    'GD@15': '-169',
#    'CSD@15': '-5',
#    'XPD@15': '-133',
#    'FB %': '22.9%',
#    'FB Victim': '7.2%',
#    'Penta Kills': '0',
#    'Solo Kills': '2',
#    'Season': 'S14'},
#   'Pollu': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '68',
#    'Win rate': '22.1%',
#    'KDA': '1.9',
#    'Avg kills': '0.6',
#    'Avg deaths': '3.8',
#    'Avg assists': '6.6',
#    'CSM': '1.1',
#    'GPM': '232',
#    'KP%': '69.9%',
#    'DMG%': '7.4',
#    'DPM': '157',
#    'VSPM': '3.29',
#    'Avg WPM': '1.8',
#    'Avg WCPM': '0.39',
#    'Avg VWPM': '0.53',
#    'GD@15': '-327',
#    'CSD@15': '-15',
#    'XPD@15': '-536',
#    'FB %': '33.8%',
#    'FB Victim': '8.8%',
#    'Penta Kills': '0',
#    'Solo Kills': '1',
#    'Season': 'S14'},
#   'Quantum': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '14',
#    'Win rate': '28.6%',
#    'KDA': '1.4',
#    'Avg kills': '0.6',
#    'Avg deaths': '4.5',
#    'Avg assists': '5.7',
#    'CSM': '1.2',
#    'GPM': '239',
#    'KP%': '59.8%',
#    'DMG%': '11.1',
#    'DPM': '240',
#    'VSPM': '3.58',
#    'Avg WPM': '1.96',
#    'Avg WCPM': '0.5',
#    'Avg VWPM': '0.47',
#    'GD@15': '-247',
#    'CSD@15': '1',
#    'XPD@15': '-242',
#    'FB %': '7.1%',
#    'FB Victim': '28.6%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'},
#   'Vital': {'Country': 'KR',
#    'Position': 'SUPPORT',
#    'Games': '11',
#    'Win rate': '45.5%',
#    'KDA': '2.9',
#    'Avg kills': '0.6',
#    'Avg deaths': '3.5',
#    'Avg assists': '9.5',
#    'CSM': '1.3',
#    'GPM': '257',
#    'KP%': '75.2%',
#    'DMG%': '8.7',
#    'DPM': '203',
#    'VSPM': '3.75',
#    'Avg WPM': '1.75',
#    'Avg WCPM': '0.64',
#    'Avg VWPM': '0.47',
#    'GD@15': '102',
#    'CSD@15': '3',
#    'XPD@15': '485',
#    'FB %': '54.5%',
#    'FB Victim': '0%',
#    'Penta Kills': '0',
#    'Solo Kills': '-',
#    'Season': 'S14'}}]

# %%
player_spring = collect_player("spring","S14")
